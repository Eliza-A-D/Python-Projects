# %% [markdown]
# # Analysis of Ebay Car Sales Data
# Goal: clean and analyse the included used car listings.
# # Dataset
# I will work on the autos.csv data set to perform my analysis. This is a data set of used cars from eBay Kleinanzeigen.

# %% [markdown]
# | Columns            | Definition                  |
# | ------------------ | --------------------------- |
# | dateCrawled        | When ad was first crawled   |
# | name               | Name of the car             |
# | seller             | Seller private or dealer    |
# | offerType          | The type of listing         |
# | price              | Price on ad to sell the car |
# | abtest             | Listing included in A/B test|
# | vechileType        | The vehicle type            |
# | yearOfRegistration | Year car first registered   |
# | gearbox            | The transmission type       |
# | powerPS            | Power of the car in PS      |
# | model              | Car model name              |
# | kilometer          | How many kms car has driven |
# | monthOfRegistration| Month car first registered  |
# | fuelType           | Type of fuel the car uses   |
# | brand              | Brand of the car            |
# | notRepairedDamage  | Car has damage not repaired |
# | dateCreated        | Date eBay listing created   |
# | nrOfPictures       | Number of pictures in ad    |
# | postalCode         | Postal code for location    |
# | lastSeenOnline     | Crawler last saw ad online  |

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# Importing data set

# %%
autos = pd.read_csv("C:\\Users\\eliza\\OneDrive\\Documents\\Grayce\\Training\\Guided_Project3\\data-society-used-cars-data\\autos.csv", encoding="Latin-1")

# %% [markdown]
# # Initial Analysis of Data Set

# %%
autos.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %%
autos.describe()
# Out:
#               price  yearOfRegistration        powerPS      kilometer  \
# count  3.715280e+05       371528.000000  371528.000000  371528.000000
# mean   1.729514e+04         2004.577997     115.549477  125618.688228
# std    3.587954e+06           92.866598     192.139578   40112.337051
# min    0.000000e+00         1000.000000       0.000000    5000.000000
# 25%    1.150000e+03         1999.000000      70.000000  125000.000000
# 50%    2.950000e+03         2003.000000     105.000000  150000.000000
# 75%    7.200000e+03         2008.000000     150.000000  150000.000000
# max    2.147484e+09         9999.000000   20000.000000  150000.000000
#
#        monthOfRegistration  nrOfPictures    postalCode
# count        371528.000000      371528.0  371528.00000
# mean              5.734445           0.0   50820.66764
# std               3.712412           0.0   25799.08247
# min               0.000000           0.0    1067.00000
# 25%               3.000000           0.0   30459.00000
# 50%               6.000000           0.0   49610.00000
# 75%               9.000000           0.0   71546.00000
# max              12.000000           0.0   99998.00000

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
#  15  notRepairedDamage    299468 non-null  object
#  16  dateCreated          371528 non-null  object
#  17  nrOfPictures         371528 non-null  int64
#  18  postalCode           371528 non-null  int64
#  19  lastSeen             371528 non-null  object
# dtypes: int64(7), object(13)
# memory usage: 56.7+ MB

# %% [markdown]
# From initial analysis of the data set, vehicleType, gearbox, model, fuelType, notRepairedDamage all contain null values. These will need to be addressed. Seven columns are int64 type and the other 13 columns are object type. There are 20 columns in total. The minimum price is £0.00, which may need to be investigated.

# %% [markdown]
# # Changing column names

# %% [markdown]
# Existing columns

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %% [markdown]
# Updating column names

# %%
import stringcase

column_name_list = []

for a in autos.columns:
    a = a.replace('yearOfRegistration','registration_year')
    a = a.replace('monthOfRegistration','registration_month')
    a = a.replace('notRepairedDamage','unrepaired_damage')
    a = a.replace('dateCreated','ad_created')
    # Converting from camelcase to snakecase
    new_string = stringcase.snakecase(a)
    column_name_list.append(new_string)
    
autos.columns = column_name_list

# %%
autos.head()
# Out:
#           date_crawled                            name  seller offer_type  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat    Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat    Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat    Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat    Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat    Angebot
#
#    price abtest vehicle_type  registration_year    gearbox  power_p_s  model  \
# 0    480   test          NaN               1993    manuell          0   golf
# 1  18300   test        coupe               2011    manuell        190    NaN
# 2   9800   test          suv               2004  automatik        163  grand
# 3   1500   test   kleinwagen               2001    manuell         75   golf
# 4   3600   test   kleinwagen               2008    manuell         69  fabia
#
#    kilometer  registration_month fuel_type       brand unrepaired_damage  \
# 0     150000                   0    benzin  volkswagen               NaN
# 1     125000                   5    diesel        audi                ja
# 2     125000                   8    diesel        jeep               NaN
# 3     150000                   6    benzin  volkswagen              nein
# 4      90000                   7    diesel       skoda              nein
#
#             ad_created  nr_of_pictures  postal_code            last_seen
# 0  2016-03-24 00:00:00               0        70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00               0        66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00               0        90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00               0        91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00               0        60437  2016-04-06 10:17:21

# %% [markdown]
# I have changed the names of the columns to give a better description of their contents.

# %% [markdown]
# # Cleaning data further

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type         price  \
# count                371528       371528  371528     371528  3.715280e+05
# unique               280500       233531       2          2           NaN
# top     2016-03-24 14:49:47  Ford_Fiesta  privat    Angebot           NaN
# freq                      7          657  371525     371516           NaN
# mean                    NaN          NaN     NaN        NaN  1.729514e+04
# std                     NaN          NaN     NaN        NaN  3.587954e+06
# min                     NaN          NaN     NaN        NaN  0.000000e+00
# 25%                     NaN          NaN     NaN        NaN  1.150000e+03
# 50%                     NaN          NaN     NaN        NaN  2.950000e+03
# 75%                     NaN          NaN     NaN        NaN  7.200000e+03
# max                     NaN          NaN     NaN        NaN  2.147484e+09
#
#         abtest vehicle_type  registration_year  gearbox      power_p_s  \
# count   371528       333659      371528.000000   351319  371528.000000
# unique       2            8                NaN        2            NaN
# top       test    limousine                NaN  manuell            NaN
# freq    192585        95894                NaN   274214            NaN
# mean       NaN          NaN        2004.577997      NaN     115.549477
# std        NaN          NaN          92.866598      NaN     192.139578
# min        NaN          NaN        1000.000000      NaN       0.000000
# 25%        NaN          NaN        1999.000000      NaN      70.000000
# 50%        NaN          NaN        2003.000000      NaN     105.000000
# 75%        NaN          NaN        2008.000000      NaN     150.000000
# max        NaN          NaN        9999.000000      NaN   20000.000000
#
#          model      kilometer  registration_month fuel_type       brand  \
# count   351044  371528.000000       371528.000000    338142      371528
# unique     251            NaN                 NaN         7          40
# top       golf            NaN                 NaN    benzin  volkswagen
# freq     30070            NaN                 NaN    223857       79640
# mean       NaN  125618.688228            5.734445       NaN         NaN
# std        NaN   40112.337051            3.712412       NaN         NaN
# min        NaN    5000.000000            0.000000       NaN         NaN
# 25%        NaN  125000.000000            3.000000       NaN         NaN
# 50%        NaN  150000.000000            6.000000       NaN         NaN
# 75%        NaN  150000.000000            9.000000       NaN         NaN
# max        NaN  150000.000000           12.000000       NaN         NaN
#
#        unrepaired_damage           ad_created  nr_of_pictures   postal_code  \
# count             299468               371528        371528.0  371528.00000
# unique                 2                  114             NaN           NaN
# top                 nein  2016-04-03 00:00:00             NaN           NaN
# freq              263182                14450             NaN           NaN
# mean                 NaN                  NaN             0.0   50820.66764
# std                  NaN                  NaN             0.0   25799.08247
# min                  NaN                  NaN             0.0    1067.00000
# 25%                  NaN                  NaN             0.0   30459.00000
# 50%                  NaN                  NaN             0.0   49610.00000
# 75%                  NaN                  NaN             0.0   71546.00000
# max                  NaN                  NaN             0.0   99998.00000
#
#                   last_seen
# count                371528
# unique               182806
# top     2016-04-06 13:45:54
# freq                     17
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
autos.describe()
# Out:
#               price  registration_year      power_p_s      kilometer  \
# count  3.715280e+05      371528.000000  371528.000000  371528.000000
# mean   1.729514e+04        2004.577997     115.549477  125618.688228
# std    3.587954e+06          92.866598     192.139578   40112.337051
# min    0.000000e+00        1000.000000       0.000000    5000.000000
# 25%    1.150000e+03        1999.000000      70.000000  125000.000000
# 50%    2.950000e+03        2003.000000     105.000000  150000.000000
# 75%    7.200000e+03        2008.000000     150.000000  150000.000000
# max    2.147484e+09        9999.000000   20000.000000  150000.000000
#
#        registration_month  nr_of_pictures   postal_code
# count       371528.000000        371528.0  371528.00000
# mean             5.734445             0.0   50820.66764
# std              3.712412             0.0   25799.08247
# min              0.000000             0.0    1067.00000
# 25%              3.000000             0.0   30459.00000
# 50%              6.000000             0.0   49610.00000
# 75%              9.000000             0.0   71546.00000
# max             12.000000             0.0   99998.00000

# %% [markdown]
# I can drop columns that have mostly one value, these include `seller` and `offer_type`. `nr_of_pictures` just seems to have the value `0` so can also be dropped.

# %%
autos.dtypes
# Out:
# date_crawled          object
# name                  object
# seller                object
# offer_type            object
# price                  int64
# abtest                object
# vehicle_type          object
# registration_year      int64
# gearbox               object
# power_p_s              int64
# model                 object
# kilometer              int64
# registration_month     int64
# fuel_type             object
# brand                 object
# unrepaired_damage     object
# ad_created            object
# nr_of_pictures         int64
# postal_code            int64
# last_seen             object
# dtype: object

# %% [markdown]
# # Analysing `kilometer` and `price` columns

# %% [markdown]
# Starting with the `kilometer` column:

# %%
autos["kilometer"].unique() # Lists the unique values
# Out:
# array([150000, 125000,  90000,  40000,  30000,  70000,   5000, 100000,
#         60000,  20000,  80000,  50000,  10000], dtype=int64)

# %%
autos["kilometer"].unique().shape # There are 13 unique values
# Out:
# (13,)

# %%
autos["kilometer"].describe()
# Out:
# count    371528.000000
# mean     125618.688228
# std       40112.337051
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: kilometer, dtype: float64

# %%
autos["kilometer"].value_counts()
# Out:
# 150000    240797
# 125000     38067
# 100000     15920
# 90000      12523
# 80000      11053
# 70000       9773
# 60000       8669
# 50000       7615
# 5000        7069
# 40000       6376
# 30000       6041
# 20000       5676
# 10000       1949
# Name: kilometer, dtype: int64

# %% [markdown]
# The column `kilometer` has reasonable values, even though above the 50% percentile is 150000.

# %% [markdown]
# Looking at the `price` column:

# %%
autos["price"].unique()
# Out:
# array([  480, 18300,  9800, ..., 18429, 24895, 10985], dtype=int64)

# %%
autos["price"].unique().shape
# Out:
# (5597,)

# %%
autos["price"].describe()
# Out:
# count    3.715280e+05
# mean     1.729514e+04
# std      3.587954e+06
# min      0.000000e+00
# 25%      1.150000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      2.147484e+09
# Name: price, dtype: float64

# %%
autos["price"].value_counts()
# Out:
# 0         10778
# 500        5670
# 1500       5394
# 1000       4649
# 1200       4594
#           ...
# 23456         1
# 171000        1
# 21830         1
# 13485         1
# 8188          1
# Name: price, Length: 5597, dtype: int64

# %% [markdown]
# Looking at the least common 20 prices

# %%
autos["price"].value_counts(ascending=True).head(20)
# Out:
# 8188      1
# 13485     1
# 21830     1
# 171000    1
# 23456     1
# 30530     1
# 42840     1
# 12973     1
# 2730      1
# 145900    1
# 8265      1
# 77        1
# 10670     1
# 4175      1
# 28995     1
# 14666     1
# 19269     1
# 3755      1
# 31555     1
# 588       1
# Name: price, dtype: int64

# %% [markdown]
# Looking at the most common 20 prices

# %%
autos["price"].value_counts(ascending=False).head(20)
# Out:
# 0       10778
# 500      5670
# 1500     5394
# 1000     4649
# 1200     4594
# 2500     4438
# 600      3819
# 3500     3792
# 800      3784
# 2000     3432
# 999      3364
# 750      3203
# 650      3150
# 4500     3053
# 850      2946
# 2200     2936
# 700      2936
# 1800     2886
# 900      2874
# 950      2793
# Name: price, dtype: int64

# %% [markdown]
# `Price` should not be `$0`, so I will remove all 10778 entries with a price of `$0`

# 54507                    Tausch_DKW_F8_gegen_Lanz_Bulldog  privat    Angebot
# 177744                     Suche_Trabant_auf_Ratenzahlung  privat    Angebot
# 210657   Escort_MK_1_Hundeknochen_zum_umbauen_auf_RS_2000  privat    Angebot
# 338415                         Polo_6n_gti__Zustand_egal_  privat    Angebot
# 332028                     Golf_3_Gti_"16v_Turbo_vr6_bbs"  privat    Angebot
# 287835                                 tausche_o_verkaufe  privat    Angebot
# 266124  Audi_A4_b7_8e_no_airride_static_20_Zoll_nur_Ta...  privat    Angebot
# 241847  Opel_Vectra_B_1_6i_16V_Facelift_Tuning_Showcar...  privat    Angebot
# 310924                     Wer_will_mich_kleinen_polo_6n1  privat    Angebot
# 39625                         Tausche_volvo_v40_gegen_van  privat    Angebot
# 217547                                         Fiat_Punto  privat    Angebot
# 299872                          Vw_polo_6n_Colour_Concept  privat    Angebot
# 20746                                  Golf3_Schlachtfest  privat    Angebot
# 273145                                         Fiat_Punto  privat    Angebot
# 279937  Mercedes_Benz_CLK_Coupe_280_7G_TRONIC_Sport_Av...  privat    Angebot
# 87799                                   Leasinguebernahme  privat    Angebot
# 183361  BMW_e60_nur_Tausch_prins_gasanlage_20_Zoll!_No...  privat    Angebot
# 120919                ???_?_???____???_?_???____???_?_???  privat    Angebot
# 251980   Audi_A6_2.7_TDI_quattro_S_Line_Luftfederung_Bose  privat    Angebot
# 362782        Passat_35i_1.8_90ps_Kombi_frisch_lackiert_!  privat    Angebot
# 150909                     Suche_Autos_Model_egal_welches  privat    Angebot
# 246635                          Suche_Vw_Passat..........  privat    Angebot
# 108987  Biete_Hier_zum_Tauschen_an_aber_nur_realistisc...  privat    Angebot
# 127820                                   audi_a6_c5_avant  privat    Angebot
# 280059  Kaufe_VW_Golf_1_auch_ohne_TÜV_________________...  privat    Angebot
# 69747                    Suche_Mercedes_Benz_r_klasse_cdi  privat    Angebot
# 77520                         Tausch_gegen_gleichwertiges  privat    Angebot
# 139052                Mercedes_Benz_CLS_350_CDI_7G_TRONIC  privat    Angebot
# 268173                           Schlachte_e36_325i_Umbau  privat    Angebot
# 325589        Tausche/_verkaufe_Golf_1_LX_mit_H_Zulassung  privat    Angebot
# 56973     tausche_ford_mondeo_mk3_ghia_gegen_anderes_auto  privat    Angebot
# 160530                                     Golf_4_schrott  privat    Angebot
# 366653      BMW_E36_Cabrio_tausch_gegen_ein_Opel_Insignia  privat    Angebot
# 189737                         Oldtimer_Goggo_Transporter  privat    Angebot
# 129969                            Kaufe_AUTOS_Zum_basteln  privat    Angebot
#
#              price   abtest vehicle_type  registration_year    gearbox  \
# 91106      9999999     test    limousine               1996    manuell
# 54295     10000000  control          bus               2007    manuell
# 176070    10000000     test          NaN               1985  automatik
# 281833    10000000     test          NaN               2019    manuell
# 358868    10000000  control        kombi               2002    manuell
# 363434    10000000     test        kombi               1996    manuell
# 121793    10000000  control          NaN               1910        NaN
# 171824    10000000  control        coupe               1960    manuell
# 196306    10000000  control          NaN               2017    manuell
# 361451    10010011     test          NaN               2000        NaN
# 14663     11111111  control        coupe               2003    manuell
# 127769    11111111     test    limousine               2003    manuell
# 185227    11111111     test          NaN               2000        NaN
# 318143    11111111     test          NaN               1995        NaN
# 90853     11111111  control          NaN               2018        NaN
# 54507     11111111     test       andere               1953    manuell
# 177744    11111111  control          NaN               1960        NaN
# 210657    11111111     test    limousine               1973    manuell
# 338415    11111111     test          NaN               2000        NaN
# 332028    11111111  control          NaN               1995        NaN
# 287835    12345678     test        kombi               2001    manuell
# 266124    12345678  control          NaN               2006        NaN
# 241847    12345678  control    limousine               2001    manuell
# 310924    12345678     test   kleinwagen               1997    manuell
# 39625     12345678  control          NaN               2018    manuell
# 217547    12345678     test   kleinwagen               2003    manuell
# 299872    12345678     test   kleinwagen               1996    manuell
# 20746     12345678     test          NaN               1995        NaN
# 273145    12345678  control          NaN               2017        NaN
# 279937    14000500  control        coupe               2008  automatik
# 87799     27322222  control    limousine               2014    manuell
# 183361    32545461  control    limousine               2004  automatik
# 120919    74185296     test          NaN               2000        NaN
# 251980    99000000     test    limousine               2009  automatik
# 362782    99999999     test          NaN               1995        NaN
# 150909    99999999     test          NaN               1990        NaN
# 246635    99999999     test          NaN               2000        NaN
# 108987    99999999     test          NaN               2017    manuell
# 127820    99999999     test        kombi               1999    manuell
# 280059    99999999  control       andere               1974    manuell
# 69747     99999999  control          bus               2006        NaN
# 77520     99999999  control    limousine               1999  automatik
# 139052    99999999  control        coupe               2009  automatik
# 268173    99999999     test        coupe               1992        NaN
# 325589    99999999     test    limousine               1983    manuell
# 56973     99999999  control    limousine               2002    manuell
# 160530    99999999     test   kleinwagen               2001        NaN
# 366653    99999999  control       cabrio               1996    manuell
# 189737    99999999  control   kleinwagen               1956    manuell
# 129969  2147483647     test       andere               1996    manuell
#
#         power_p_s     model  kilometer  registration_month fuel_type  \
# 91106         380        a4      60000                   5    benzin
# 54295         143   5_reihe     150000                   2    diesel
# 176070        300       NaN     150000                   0       NaN
# 281833         10       NaN       5000                   0       NaN
# 358868          0       NaN     150000                   7    diesel
# 363434         90       NaN     150000                   0    benzin
# 121793          0    kaefer     100000                   0       NaN
# 171824        368       NaN     100000                   1    benzin
# 196306          0      golf       5000                   0    benzin
# 361451          0       NaN     150000                   0       NaN
# 14663          64      polo     150000                   2    benzin
# 127769         75      golf     125000                   9    benzin
# 185227          0       NaN       5000                   0       NaN
# 318143          0       NaN     150000                   0       NaN
# 90853           0       NaN     150000                   0       NaN
# 54507          20       NaN     150000                   5       NaN
# 177744          0       NaN     150000                   0       NaN
# 210657         48    escort      50000                   3    benzin
# 338415        120      polo     125000                   0    benzin
# 332028        116      golf     150000                   6    benzin
# 287835        101     focus     150000                   0    benzin
# 266124          0        a4     150000                   0       NaN
# 241847        101    vectra     150000                   3    benzin
# 310924         45       NaN     150000                   7    benzin
# 39625          95       v40     150000                   6       NaN
# 217547         60     punto      80000                   0       NaN
# 299872         60      polo     150000                   0       NaN
# 20746           0       NaN     150000                   0       NaN
# The car prices seem much too high. I will just keep price for between `$1` and `$400,000`

# %%
autos = autos[(autos["price"] >= 1) & (autos["price"] <= 400000)]

# %% [markdown]
# # Exploring the date columns

# %% [markdown]
# These columns include:
# - `date_crawled`: added by the crawler
# - `last_seen`: added by the crawler
# - `ad_created`: from the website
# - `registration_month`: from the website
# - `registration_year`: from the website

# %% [markdown]
# Currently, `date_crawled`, `last_seen`, and `ad_created` columns are all identified as string values by pandas. Let us look at how we can make use of these columns better for our analysis.

# %%
autos[["date_crawled","last_seen","ad_created"]].head(10)
# Out:
#            date_crawled            last_seen           ad_created
# 0   2016-03-24 11:52:17  2016-04-07 03:16:57  2016-03-24 00:00:00
# 1   2016-03-24 10:58:45  2016-04-07 01:46:50  2016-03-24 00:00:00
# 2   2016-03-14 12:52:21  2016-04-05 12:47:46  2016-03-14 00:00:00
# 3   2016-03-17 16:54:04  2016-03-17 17:40:17  2016-03-17 00:00:00
# 4   2016-03-31 17:25:20  2016-04-06 10:17:21  2016-03-31 00:00:00
# 5   2016-04-04 17:36:23  2016-04-06 19:17:07  2016-04-04 00:00:00
# 6   2016-04-01 20:48:51  2016-04-05 18:18:39  2016-04-01 00:00:00
# 8   2016-04-04 23:42:13  2016-04-04 23:42:13  2016-04-04 00:00:00
# 9   2016-03-17 10:53:50  2016-03-31 17:17:06  2016-03-17 00:00:00
# 10  2016-03-26 19:54:18  2016-04-06 10:45:34  2016-03-26 00:00:00

# %% [raw]
# Removing the timestamp so we can see the date values

# %%
# Reassign the cleaned values back to the columns
autos["date_crawled"]=autos["date_crawled"].str[:10]
autos["last_seen"]=autos["last_seen"].str[:10]
autos["ad_created"]=autos["ad_created"].str[:10]

# %%
# Further analysis of date_crawled column
autos["date_crawled"].value_counts(normalize=True).sort_index(ascending=True)
# Out:
# 2016-03-05    0.025546
# 2016-03-06    0.014483
# 2016-03-07    0.035656
# 2016-03-08    0.033468
# 2016-03-09    0.034114
# 2016-03-10    0.032647
# 2016-03-11    0.032772
# 2016-03-12    0.036241
# 2016-03-13    0.015783
# 2016-03-14    0.036330
# 2016-03-15    0.033424
# 2016-03-16    0.030205
# 2016-03-17    0.031649
# 2016-03-18    0.013118
# 2016-03-19    0.035271
# 2016-03-20    0.036399
# 2016-03-21    0.035681
# 2016-03-22    0.032492
# 2016-03-23    0.032004
# 2016-03-24    0.029913
# 2016-03-25    0.032800
# 2016-03-26    0.031974
# 2016-03-27    0.030227
# 2016-03-28    0.035063
# 2016-03-29    0.034125
# 2016-03-30    0.033535
# 2016-03-31    0.031874
# 2016-04-01    0.034145
# 2016-04-02    0.035096
# 2016-04-03    0.038811
# 2016-04-04    0.037627
# 2016-04-05    0.012783
# 2016-04-06    0.003128
# 2016-04-07    0.001617
# Name: date_crawled, dtype: float64

# %%
# Further analysis of last_seen column
autos["last_seen"].value_counts(normalize=True).sort_index(ascending=True)
# Out:
# 2016-03-05    0.001264
# 2016-03-06    0.004098
# 2016-03-07    0.005202
# 2016-03-08    0.007939
# 2016-03-09    0.009824
# 2016-03-10    0.011460
# 2016-03-11    0.012955
# 2016-03-12    0.023239
# 2016-03-13    0.008410
# 2016-03-14    0.012176
# 2016-03-15    0.016324
# 2016-03-16    0.016418
# 2016-03-17    0.028702
# 2016-03-18    0.006888
# 2016-03-19    0.016329
# 2016-03-20    0.019884
# 2016-03-21    0.020025
# 2016-03-22    0.020508
# 2016-03-23    0.018015
# 2016-03-24    0.019163
# 2016-03-25    0.019000
# 2016-03-26    0.015958
# 2016-03-27    0.016720
# 2016-03-28    0.022188
# 2016-03-29    0.023284
# 2016-03-30    0.023724
# 2016-03-31    0.024243
# 2016-04-01    0.023896
# 2016-04-02    0.024967
# 2016-04-03    0.025310
# 2016-04-04    0.025535
# 2016-04-05    0.126968
# 2016-04-06    0.218949
# 2016-04-07    0.130434
# Name: last_seen, dtype: float64

# %%
# Further analysis of ad_created column
autos["ad_created"].value_counts(normalize=True).sort_index(ascending=True)
# Out:
# 2014-03-10    0.000003
# 2015-03-20    0.000003
# 2015-06-11    0.000003
# 2015-06-18    0.000003
# 2015-08-07    0.000003
#                 ...
# 2016-04-03    0.039000
# 2016-04-04    0.037736
# 2016-04-05    0.011615
# 2016-04-06    0.003119
# 2016-04-07    0.001553
# Name: ad_created, Length: 114, dtype: float64

# %% [markdown]
# `last_seen` and `date_crawled` columns are similar. It was more popular to create ads in 2016.

# %% [markdown]
# # Registration year

# %%
autos["registration_year"].describe()
# Out:
# count    360641.000000
# mean       2004.433023
# std          81.016330
# min        1000.000000
# 25%        1999.000000
# 50%        2004.000000
# 75%        2008.000000
# max        9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# The minimum registration year is `1000`, before cars were invented. The maximum registration year is `9999`, which hasn't happened yet. So neither of these are valid.

# %% [markdown]
# I have decided to only include cars from the 1900-2016.

# %%
autos = autos[(autos["registration_year"] >= 1900) & (autos["registration_year"] <= 2016)]

# %%
autos["registration_year"].value_counts(normalize=True)
# Out:
# 2000    0.066698
# 1999    0.063551
# 2005    0.062668
# 2006    0.057707
# 2001    0.056957
#           ...
# 1928    0.000006
# 1927    0.000006
# 1940    0.000006
# 1925    0.000003
# 1911    0.000003
# Name: registration_year, Length: 94, dtype: float64

# %% [markdown]
# More cars are made recently, with fewer registered back to the early 1900s.

# %% [markdown]
# # Exploring Price by Brand

# %%
autos["brand"].unique()
# Out:
# array(['volkswagen', 'audi', 'jeep', 'skoda', 'bmw', 'peugeot', 'ford',
#        'mazda', 'nissan', 'renault', 'mercedes_benz', 'seat', 'honda',
#        'fiat', 'opel', 'mini', 'smart', 'hyundai', 'sonstige_autos',
#        'alfa_romeo', 'subaru', 'volvo', 'mitsubishi', 'kia', 'suzuki',
#        'lancia', 'porsche', 'citroen', 'toyota', 'chevrolet', 'dacia',
#        'daihatsu', 'trabant', 'chrysler', 'jaguar', 'daewoo', 'rover',
#        'saab', 'land_rover', 'lada'], dtype=object)

# %%
autos["brand"].value_counts()
# Out:
# volkswagen        73388
# bmw               38089
# opel              36888
# mercedes_benz     33572
# audi              31041
# ford              23891
# renault           16472
# peugeot           10453
# fiat               8906
# seat               6469
# skoda              5438
# mazda              5333
# smart              4968
# citroen            4836
# nissan             4714
# toyota             4483
# hyundai            3457
# sonstige_autos     3293
# mini               3253
# volvo              3171
# mitsubishi         2855
# honda              2611
# kia                2397
# suzuki             2206
# alfa_romeo         2187
# porsche            2155
# chevrolet          1741
# chrysler           1339
# dacia               865
# jeep                760
# land_rover          751
# daihatsu            749
# subaru              734
# jaguar              601
# saab                508
# daewoo              505
# trabant             488
# lancia              451
# rover               441
# lada                207
# Name: brand, dtype: int64

# %% [markdown]
# I have chosen to aggregate on the top 10 brands.

# %%
selected_brands= autos["brand"].value_counts().head(10).index

# %%
brand_mean_price = {}
brand_mean_mileage = {}
for a in selected_brands:
    brand_rows = autos[autos["brand"] == a]
    mean_price = brand_rows["price"].mean() # Calculating the mean price for this subset of the data
    mean_mileage = brand_rows["kilometer"].mean() # Calculating the mean milage for this subset of the data
    brand_mean_price[a] = round(mean_price, 2)
    brand_mean_mileage[a] = round(mean_mileage, 2)

# %% [markdown]
# Out of the ten most common cars, Audi is the most expensive on average, and Renault is the least expensive on average.

# %% [markdown]
# Converting both dictionaries to series objects using the series constructor.

# %%
bmp_series = pd.Series(brand_mean_price)
bmm_series = pd.Series(brand_mean_mileage)

# %%
print(bmp_series)
# Out:
# volkswagen       5400.19
# bmw              8459.14
# opel             2971.90
# mercedes_benz    8562.36
# audi             9086.28
# ford             3696.41
# renault          2437.61
# peugeot          3267.61
# fiat             2892.95
# seat             4542.00
# dtype: float64

# %%
print(bmm_series)
# Out:
# volkswagen       128386.04
# bmw              132796.74
# opel             128722.62
# mercedes_benz    130569.97
# audi             129443.96
# ford             123662.26
# renault          127885.20
# peugeot          124500.62
# fiat             116619.69
# seat             120608.29
# dtype: float64

# %% [markdown]
# Creating a dataframe

# %%
df = pd.DataFrame(bmp_series, columns=["mean_price"])

# %%
df
# Out:
#                mean_price
# volkswagen        5400.19
# bmw               8459.14
# opel              2971.90
# mercedes_benz     8562.36
# audi              9086.28
# ford              3696.41
# renault           2437.61
# peugeot           3267.61
# fiat              2892.95
# seat              4542.00

# %% [markdown]
# Adding the other column

# %%
df["mean_mileage"] = bmm_series

# %%
df
# Out:
#                mean_price  mean_mileage
# volkswagen        5400.19     128386.04
# bmw               8459.14     132796.74
# opel              2971.90     128722.62
# mercedes_benz     8562.36     130569.97
# audi              9086.28     129443.96
# ford              3696.41     123662.26
# renault           2437.61     127885.20
# peugeot           3267.61     124500.62
# fiat              2892.95     116619.69
# seat              4542.00     120608.29

# %% [markdown]
# The average mileage does not strongly influence the mean price of the car. The more expensive cars have a slightly higher mean mileage than the others, but it is not significant.

# %%
df["mean_mileage"].describe()
# Out:
# count        10.000000
# mean     126319.539000
# std        4936.866481
# min      116619.690000
# 25%      123871.850000
# 50%      128135.620000
# 75%      129263.625000
# max      132796.740000
# Name: mean_mileage, dtype: float64
